# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('HousingData.csv',na_values='NA')
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         B  LSTAT  MEDV
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90    NaN  36.2

# %%
df.columns
# Out:
# Index(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX',
#        'PTRATIO', 'B', 'LSTAT', 'MEDV'],
#       dtype='object')

# %%
df.isna().sum()
# Out:
# CRIM       20
# ZN         20
# INDUS      20
# CHAS       20
# NOX         0
# RM          0
# AGE        20
# DIS         0
# RAD         0
# TAX         0
# PTRATIO     0
# B           0
# LSTAT      20
# MEDV        0
# dtype: int64

# %%
df.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  486.000000  486.000000  486.000000  486.000000  506.000000  506.000000
# mean     3.611874   11.211934   11.083992    0.069959    0.554695    6.284634
# std      8.720192   23.388876    6.835896    0.255340    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.081900    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.253715    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.560263   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  486.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.518519    3.795043    9.549407  408.237154   18.455534  356.674032
# std     27.999513    2.105710    8.707259  168.537116    2.164946   91.294864
# min      2.900000    1.129600    1.000000  187.000000   12.600000    0.320000
# 25%     45.175000    2.100175    4.000000  279.000000   17.400000  375.377500
# 50%     76.800000    3.207450    5.000000  330.000000   19.050000  391.440000
# 75%     93.975000    5.188425   24.000000  666.000000   20.200000  396.225000
# max    100.000000   12.126500   24.000000  711.000000   22.000000  396.900000
#
#             LSTAT        MEDV
# count  486.000000  506.000000
# mean    12.715432   22.532806
# std      7.155871    9.197104
# min      1.730000    5.000000
# 25%      7.125000   17.025000
# 50%     11.430000   21.200000
# 75%     16.955000   25.000000
# max     37.970000   50.000000

# %%
for i in df.columns:
    mean_value = df[i].mean()
    df[i].fillna(mean_value, inplace=True)

# %%
df.isna().sum()
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# MEDV       0
# dtype: int64

# %%
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         B      LSTAT  MEDV
# 0  396.90   4.980000  24.0
# 1  396.90   9.140000  21.6
# 2  392.83   4.030000  34.7
# 3  394.63   2.940000  33.4
# 4  396.90  12.715432  36.2

# %%
from sklearn.model_selection import train_test_split

X = df.loc[:, df.columns != 'MEDV']
y = df.loc[:, df.columns == 'MEDV']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=123)

# %%
from sklearn.preprocessing import MinMaxScaler
mms = MinMaxScaler()
mms.fit(X_train)
X_train = mms.transform(X_train)
X_test = mms.transform(X_test)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

model = Sequential()

model.add(Dense(128, input_shape=(13, ), activation='relu', name='dense_1'))
model.add(Dense(64, activation='relu', name='dense_2'))
model.add(Dense(1, activation='linear', name='dense_output'))

model.compile(optimizer='adam', loss='mse', metrics=['mae'])
model.summary()
# Out:
# 2024-04-28 21:17:40.999466: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-04-28 21:17:40.999699: I external/local_tsl/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-04-28 21:17:41.001610: I external/local_tsl/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-04-28 21:17:41.026002: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-04-28 21:17:41.481578: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /home/ruturaj-ubuntu/anaconda3/lib/python3.11/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_1 (Dense)                 │ (None, 128)            │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_output (Dense)            │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 10,113 (39.50 KB)
#  Trainable params: 10,113 (39.50 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
history = model.fit(X_train, y_train, epochs=100, validation_split=0.05, verbose = 2)
# Out:
# Epoch 1/100
# 11/11 - 0s - 4ms/step - loss: 9.8158 - mae: 2.1920 - val_loss: 11.9175 - val_mae: 2.3008
# Epoch 2/100
# 11/11 - 0s - 3ms/step - loss: 10.3591 - mae: 2.1621 - val_loss: 10.1572 - val_mae: 2.2375
# Epoch 3/100
# 11/11 - 0s - 3ms/step - loss: 9.2442 - mae: 2.1075 - val_loss: 11.3090 - val_mae: 2.2716
# Epoch 4/100
# 11/11 - 0s - 3ms/step - loss: 9.3846 - mae: 2.0511 - val_loss: 10.3224 - val_mae: 2.2436
# Epoch 5/100
# 11/11 - 0s - 3ms/step - loss: 9.6291 - mae: 2.1546 - val_loss: 10.8439 - val_mae: 2.2564
# Epoch 6/100
# 11/11 - 0s - 3ms/step - loss: 9.1811 - mae: 2.0702 - val_loss: 10.0638 - val_mae: 2.1963
# Epoch 7/100
# 11/11 - 0s - 3ms/step - loss: 9.2297 - mae: 2.0659 - val_loss: 10.2762 - val_mae: 2.2229
# Epoch 8/100
# 11/11 - 0s - 3ms/step - loss: 9.3825 - mae: 2.1084 - val_loss: 10.9329 - val_mae: 2.2820
# Epoch 9/100
# 11/11 - 0s - 3ms/step - loss: 9.1800 - mae: 2.0516 - val_loss: 9.9583 - val_mae: 2.2006
# Epoch 10/100
# 11/11 - 0s - 3ms/step - loss: 9.1635 - mae: 2.0605 - val_loss: 10.2529 - val_mae: 2.2170
# Epoch 11/100
# 11/11 - 0s - 3ms/step - loss: 9.2951 - mae: 2.0810 - val_loss: 10.3537 - val_mae: 2.2385
# Epoch 12/100
# 11/11 - 0s - 3ms/step - loss: 9.5964 - mae: 2.1166 - val_loss: 9.6508 - val_mae: 2.2633
# Epoch 13/100
# 11/11 - 0s - 3ms/step - loss: 9.0821 - mae: 2.0664 - val_loss: 10.9749 - val_mae: 2.3272
# Epoch 14/100
# 11/11 - 0s - 3ms/step - loss: 9.3211 - mae: 2.0869 - val_loss: 9.1457 - val_mae: 2.1329
# Epoch 15/100
# 11/11 - 0s - 3ms/step - loss: 8.7730 - mae: 2.0355 - val_loss: 10.3649 - val_mae: 2.2177
# Epoch 16/100
# 11/11 - 0s - 3ms/step - loss: 8.9712 - mae: 2.0322 - val_loss: 9.4146 - val_mae: 2.1412
# Epoch 17/100
# 11/11 - 0s - 3ms/step - loss: 8.9244 - mae: 2.0526 - val_loss: 9.4935 - val_mae: 2.1958
# Epoch 18/100
# 11/11 - 0s - 3ms/step - loss: 8.8896 - mae: 2.0210 - val_loss: 9.2453 - val_mae: 2.1106
# Epoch 19/100
# 11/11 - 0s - 3ms/step - loss: 8.8708 - mae: 2.0286 - val_loss: 8.9790 - val_mae: 2.1300
# Epoch 20/100
# 11/11 - 0s - 3ms/step - loss: 8.7981 - mae: 2.0422 - val_loss: 8.8143 - val_mae: 2.1286
# Epoch 21/100
# 11/11 - 0s - 3ms/step - loss: 8.9552 - mae: 2.0574 - val_loss: 8.3789 - val_mae: 2.1373
# Epoch 22/100
# 11/11 - 0s - 3ms/step - loss: 8.9236 - mae: 2.0328 - val_loss: 9.7799 - val_mae: 2.1858
# Epoch 23/100
# 11/11 - 0s - 3ms/step - loss: 9.1168 - mae: 2.0773 - val_loss: 9.3883 - val_mae: 2.1462
# Epoch 24/100
# 11/11 - 0s - 3ms/step - loss: 8.6945 - mae: 2.0165 - val_loss: 8.4410 - val_mae: 2.0906
# Epoch 25/100
# 11/11 - 0s - 3ms/step - loss: 8.7113 - mae: 2.0222 - val_loss: 8.6408 - val_mae: 2.1070
# Epoch 26/100
# 11/11 - 0s - 3ms/step - loss: 8.7696 - mae: 2.0653 - val_loss: 9.2290 - val_mae: 2.1369
# Epoch 27/100
# 11/11 - 0s - 3ms/step - loss: 8.7400 - mae: 2.0396 - val_loss: 8.2812 - val_mae: 2.0440
# Epoch 28/100
# 11/11 - 0s - 3ms/step - loss: 8.5261 - mae: 1.9961 - val_loss: 8.4955 - val_mae: 2.0828
# Epoch 29/100
# 11/11 - 0s - 3ms/step - loss: 8.8652 - mae: 2.0417 - val_loss: 8.9187 - val_mae: 2.1285
# Epoch 30/100
# 11/11 - 0s - 3ms/step - loss: 8.6059 - mae: 2.0395 - val_loss: 7.9553 - val_mae: 2.0647
# Epoch 31/100
# 11/11 - 0s - 3ms/step - loss: 8.7061 - mae: 2.0355 - val_loss: 7.7267 - val_mae: 2.0195
# Epoch 32/100
# 11/11 - 0s - 3ms/step - loss: 8.3925 - mae: 1.9969 - val_loss: 8.3533 - val_mae: 2.0877
# Epoch 33/100
# 11/11 - 0s - 3ms/step - loss: 8.4870 - mae: 2.0066 - val_loss: 8.2220 - val_mae: 2.0500
# Epoch 34/100
# 11/11 - 0s - 3ms/step - loss: 8.6650 - mae: 2.0146 - val_loss: 8.0843 - val_mae: 2.0355
# Epoch 35/100
# 11/11 - 0s - 3ms/step - loss: 8.5582 - mae: 2.0129 - val_loss: 7.6167 - val_mae: 2.0854
# Epoch 36/100
# 11/11 - 0s - 3ms/step - loss: 8.7305 - mae: 2.0552 - val_loss: 8.7521 - val_mae: 2.1254
# Epoch 37/100
# 11/11 - 0s - 3ms/step - loss: 8.4008 - mae: 2.0041 - val_loss: 7.6217 - val_mae: 2.0982
# Epoch 38/100
# 11/11 - 0s - 3ms/step - loss: 8.5502 - mae: 2.0358 - val_loss: 7.2143 - val_mae: 1.9812
# Epoch 39/100
# 11/11 - 0s - 3ms/step - loss: 8.4478 - mae: 1.9911 - val_loss: 7.8678 - val_mae: 2.0292
# Epoch 40/100
# 11/11 - 0s - 3ms/step - loss: 8.5408 - mae: 2.0176 - val_loss: 7.2519 - val_mae: 1.9559
# Epoch 41/100
# 11/11 - 0s - 3ms/step - loss: 8.6162 - mae: 2.0081 - val_loss: 7.1796 - val_mae: 1.9999
# Epoch 42/100
# 11/11 - 0s - 3ms/step - loss: 8.2911 - mae: 1.9993 - val_loss: 7.5348 - val_mae: 1.9890
# Epoch 43/100
# 11/11 - 0s - 3ms/step - loss: 8.3572 - mae: 2.0198 - val_loss: 7.5023 - val_mae: 2.0196
# Epoch 44/100
# 11/11 - 0s - 3ms/step - loss: 8.4838 - mae: 1.9913 - val_loss: 7.5518 - val_mae: 2.1658
# Epoch 45/100
# 11/11 - 0s - 3ms/step - loss: 8.3360 - mae: 1.9946 - val_loss: 7.3107 - val_mae: 1.9961
# Epoch 46/100
# 11/11 - 0s - 3ms/step - loss: 8.1192 - mae: 1.9686 - val_loss: 7.2611 - val_mae: 1.9776
# Epoch 47/100
# 11/11 - 0s - 3ms/step - loss: 8.0969 - mae: 1.9577 - val_loss: 6.9789 - val_mae: 1.9494
# Epoch 48/100
# 11/11 - 0s - 3ms/step - loss: 8.1143 - mae: 1.9569 - val_loss: 6.9425 - val_mae: 1.9423
# Epoch 49/100
# 11/11 - 0s - 3ms/step - loss: 8.1365 - mae: 1.9568 - val_loss: 6.8569 - val_mae: 2.0212
# Epoch 50/100
# 11/11 - 0s - 4ms/step - loss: 8.0684 - mae: 1.9454 - val_loss: 6.9597 - val_mae: 1.9283
# Epoch 51/100
# 11/11 - 0s - 4ms/step - loss: 8.0147 - mae: 1.9388 - val_loss: 6.6610 - val_mae: 1.9193
# Epoch 52/100
# 11/11 - 0s - 4ms/step - loss: 7.9281 - mae: 1.9340 - val_loss: 6.4568 - val_mae: 2.0016
# Epoch 53/100
# 11/11 - 0s - 3ms/step - loss: 8.3127 - mae: 2.0438 - val_loss: 6.5948 - val_mae: 1.9572
# Epoch 54/100
# 11/11 - 0s - 3ms/step - loss: 8.2229 - mae: 1.9839 - val_loss: 6.5149 - val_mae: 1.9057
# Epoch 55/100
# 11/11 - 0s - 3ms/step - loss: 7.8362 - mae: 1.9473 - val_loss: 6.3332 - val_mae: 1.9391
# Epoch 56/100
# 11/11 - 0s - 3ms/step - loss: 7.8921 - mae: 1.9402 - val_loss: 6.4242 - val_mae: 1.9321
# Epoch 57/100
# 11/11 - 0s - 3ms/step - loss: 8.0637 - mae: 1.9694 - val_loss: 6.8636 - val_mae: 1.9282
# Epoch 58/100
# 11/11 - 0s - 3ms/step - loss: 7.8112 - mae: 1.9237 - val_loss: 6.0238 - val_mae: 1.8768
# Epoch 59/100
# 11/11 - 0s - 3ms/step - loss: 7.8725 - mae: 1.9717 - val_loss: 6.8143 - val_mae: 2.0429
# Epoch 60/100
# 11/11 - 0s - 3ms/step - loss: 8.1629 - mae: 2.0249 - val_loss: 6.5081 - val_mae: 2.0532
# Epoch 61/100
# 11/11 - 0s - 3ms/step - loss: 7.9561 - mae: 1.9432 - val_loss: 6.0222 - val_mae: 1.8943
# Epoch 62/100
# 11/11 - 0s - 3ms/step - loss: 7.8218 - mae: 1.9471 - val_loss: 5.7020 - val_mae: 1.8719
# Epoch 63/100
# 11/11 - 0s - 3ms/step - loss: 7.7342 - mae: 1.9341 - val_loss: 6.0164 - val_mae: 1.8628
# Epoch 64/100
# 11/11 - 0s - 3ms/step - loss: 7.6416 - mae: 1.9136 - val_loss: 6.0445 - val_mae: 1.9143
# Epoch 65/100
# 11/11 - 0s - 3ms/step - loss: 7.7727 - mae: 1.9595 - val_loss: 5.6382 - val_mae: 1.8374
# Epoch 66/100
# 11/11 - 0s - 3ms/step - loss: 7.9034 - mae: 1.9447 - val_loss: 6.4563 - val_mae: 2.0461
# Epoch 67/100
# 11/11 - 0s - 3ms/step - loss: 7.7231 - mae: 1.9382 - val_loss: 5.7891 - val_mae: 1.9277
# Epoch 68/100
# 11/11 - 0s - 3ms/step - loss: 7.5660 - mae: 1.9129 - val_loss: 5.5148 - val_mae: 1.8729
# Epoch 69/100
# 11/11 - 0s - 3ms/step - loss: 7.7299 - mae: 1.9467 - val_loss: 5.5783 - val_mae: 1.8328
# Epoch 70/100
# 11/11 - 0s - 3ms/step - loss: 7.9179 - mae: 1.9999 - val_loss: 6.1586 - val_mae: 1.9714
# Epoch 71/100
# 11/11 - 0s - 3ms/step - loss: 7.7210 - mae: 1.9790 - val_loss: 5.8656 - val_mae: 1.9674
# Epoch 72/100
# 11/11 - 0s - 4ms/step - loss: 7.4824 - mae: 1.8993 - val_loss: 5.4851 - val_mae: 1.8760
# Epoch 73/100
# 11/11 - 0s - 3ms/step - loss: 7.5461 - mae: 1.9522 - val_loss: 5.7305 - val_mae: 1.9161
# Epoch 74/100
# 11/11 - 0s - 3ms/step - loss: 7.4321 - mae: 1.9250 - val_loss: 6.0518 - val_mae: 2.0541
# Epoch 75/100
# 11/11 - 0s - 3ms/step - loss: 7.6307 - mae: 1.9227 - val_loss: 5.5064 - val_mae: 1.8497
# Epoch 76/100
# 11/11 - 0s - 3ms/step - loss: 7.5591 - mae: 1.9221 - val_loss: 5.4892 - val_mae: 1.8678
# Epoch 77/100
# 11/11 - 0s - 3ms/step - loss: 7.3181 - mae: 1.8831 - val_loss: 5.3921 - val_mae: 1.9010
# Epoch 78/100
# 11/11 - 0s - 3ms/step - loss: 7.4853 - mae: 1.9673 - val_loss: 5.9491 - val_mae: 1.9495
# Epoch 79/100
# 11/11 - 0s - 3ms/step - loss: 7.6341 - mae: 1.9879 - val_loss: 5.2577 - val_mae: 1.8224
# Epoch 80/100
# 11/11 - 0s - 3ms/step - loss: 7.2806 - mae: 1.8755 - val_loss: 5.1663 - val_mae: 1.8251
# Epoch 81/100
# 11/11 - 0s - 3ms/step - loss: 7.2215 - mae: 1.8765 - val_loss: 5.3439 - val_mae: 1.8257
# Epoch 82/100
# 11/11 - 0s - 3ms/step - loss: 7.5894 - mae: 1.9299 - val_loss: 5.8188 - val_mae: 1.9243
# Epoch 83/100
# 11/11 - 0s - 3ms/step - loss: 7.8922 - mae: 1.9603 - val_loss: 5.7076 - val_mae: 1.9959
# Epoch 84/100
# 11/11 - 0s - 3ms/step - loss: 7.1852 - mae: 1.8739 - val_loss: 5.2175 - val_mae: 1.8582
# Epoch 85/100
# 11/11 - 0s - 3ms/step - loss: 7.6029 - mae: 1.9133 - val_loss: 5.6547 - val_mae: 1.8996
# Epoch 86/100
# 11/11 - 0s - 3ms/step - loss: 7.3830 - mae: 1.8845 - val_loss: 5.6160 - val_mae: 1.9709
# Epoch 87/100
# 11/11 - 0s - 3ms/step - loss: 7.2917 - mae: 1.9074 - val_loss: 4.9245 - val_mae: 1.8158
# Epoch 88/100
# 11/11 - 0s - 3ms/step - loss: 7.3729 - mae: 1.9430 - val_loss: 5.2615 - val_mae: 1.8546
# Epoch 89/100
# 11/11 - 0s - 3ms/step - loss: 7.4546 - mae: 1.9327 - val_loss: 5.0041 - val_mae: 1.8380
# Epoch 90/100
# 11/11 - 0s - 4ms/step - loss: 7.3785 - mae: 1.8825 - val_loss: 5.3006 - val_mae: 1.9066
# Epoch 91/100
# 11/11 - 0s - 3ms/step - loss: 7.1817 - mae: 1.9066 - val_loss: 5.1481 - val_mae: 1.8619
# Epoch 92/100
# 11/11 - 0s - 3ms/step - loss: 7.2817 - mae: 1.8941 - val_loss: 4.7520 - val_mae: 1.7892
# Epoch 93/100
# 11/11 - 0s - 3ms/step - loss: 7.0988 - mae: 1.8766 - val_loss: 4.8548 - val_mae: 1.8218
# Epoch 94/100
# 11/11 - 0s - 4ms/step - loss: 7.2684 - mae: 1.9352 - val_loss: 4.7832 - val_mae: 1.8157
# Epoch 95/100
# 11/11 - 0s - 3ms/step - loss: 7.2793 - mae: 1.9315 - val_loss: 5.7694 - val_mae: 1.9832
# Epoch 96/100
# 11/11 - 0s - 3ms/step - loss: 7.5083 - mae: 1.9062 - val_loss: 4.7566 - val_mae: 1.7839
# Epoch 97/100
# 11/11 - 0s - 3ms/step - loss: 7.1815 - mae: 1.9239 - val_loss: 4.7281 - val_mae: 1.8189
# Epoch 98/100
# 11/11 - 0s - 3ms/step - loss: 7.1485 - mae: 1.9038 - val_loss: 4.6552 - val_mae: 1.7788
# Epoch 99/100
# 11/11 - 0s - 3ms/step - loss: 7.1583 - mae: 1.8882 - val_loss: 5.0676 - val_mae: 1.8682
# Epoch 100/100
# 11/11 - 0s - 3ms/step - loss: 6.8814 - mae: 1.8308 - val_loss: 4.6460 - val_mae: 1.7852

# %%
mse_nn, mae_nn = model.evaluate(X_test, y_test)

print('Mean squared error on test data: ', mse_nn)
print('Mean absolute error on test data: ', mae_nn)
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 31.9325 - mae: 3.4595
# Mean squared error on test data:  24.184972763061523
# Mean absolute error on test data:  3.1781833171844482
